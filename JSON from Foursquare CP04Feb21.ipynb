# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'
params = dict(
client_id='XLGD54MLFXRYDJTINCQ51W3QFRXDBEIEYK0XMN2EWQC3MQ41',
client_secret='BLNGXAD1SC25GFWAADU0QD14EDQADKIAPQRNLGZ4CINY1DNQ',
v='20180323',
ll='32.715736,-117.161087',
query='tacos',
limit=500
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '601cbadbd47a0161be4bb3db'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 735,
#   'headerLocation': 'Central San Diego',
#   'headerFullLocation': 'Central San Diego, San Diego',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'tacos',
#   'totalResults': 56,
#   'suggestedBounds': {'ne': {'lat': 32.73009091355917,
#     'lng': -117.15189443336844},
#    'sw': {'lat': 32.70208649831622, 'lng': -117.17682714976779}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '568daf60498eaf94b8afbc5d',
#        'name': 'The Taco Stand Downtown',
#        'contact': {},
# ...

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '601cbadbd47a0161be4bb3db'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 735,
#   'headerLocation': 'Central San Diego',
#   'headerFullLocation': 'Central San Diego, San Diego',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'tacos',
#   'totalResults': 56,
#   'suggestedBounds': {'ne': {'lat': 32.73009091355917,
#     'lng': -117.15189443336844},
#    'sw': {'lat': 32.70208649831622, 'lng': -117.17682714976779}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '568daf60498eaf94b8afbc5d',
#        'name': 'The Taco Stand Downtown',
#        'contact': {},
# ...

# %%
import json
with open('foursquareTacosLoc.json', 'w') as json_file:
    json.dump(data, json_file)

# %%
import json 
import csv 
  
  
# Python program to convert 
# JSON file to CSV 


import json 
import csv 


# Opening JSON file and loading the data 
# into the variable data 
with open('foursquareTacosLoc.json') as json_file: 
	data = json.load(json_file) 

employee_data = data['meta'] 

# now we will open a file for writing 
data_file = open('data_file.csv', 'w') 

# create the csv writer object 
csv_writer = csv.writer(data_file) 

# Counter variable used for writing 
# headers to the CSV file 
count = 0

for emp in employee_data: 
	if count == 0: 

		# Writing headers of CSV file 
		header = data.keys() 
		csv_writer.writerow(header) 
		count += 1

	# Writing data of CSV file 
	csv_writer.writerow(data.values()) 

data_file.close()
