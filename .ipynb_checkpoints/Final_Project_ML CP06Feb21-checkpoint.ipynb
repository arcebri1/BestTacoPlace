# %%
import pandas as pd
import csv
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

file = 'nba.games.stats.model.one_CP08Feb21.csv'

# %%
df = pd.read_csv(file, encoding='utf-8')
df.head()
# Out:
#   Team_Number_Id TeamPoints FieldGoals X3PointShots FreeThrows OffRebounds  \
# 0              1        102      0.500        0.591      0.529          10
# 1              1        102      0.507        0.350      0.758           3
# 2              1         92      0.413        0.320      0.727          10
# 3              1        119      0.462        0.394      0.769           7
# 4              1        103      0.407        0.409      0.778          12
#
#   TotalRebounds Assists Steals Blocks Turnovers TotalFouls
# 0            42      26      6      8        17         24
# 1            37      26     10      6        12         20
# 2            37      26     14      5        13         25
# 3            38      28      8      3        19         33
# 4            41      18     10      5         8         17

# %%
dataframe = pd.DataFrame(df)
dataframe.head()
# Out:
#   Team_Number_Id TeamPoints FieldGoals X3PointShots FreeThrows OffRebounds  \
# 0              1        102      0.500        0.591      0.529          10
# 1              1        102      0.507        0.350      0.758           3
# 2              1         92      0.413        0.320      0.727          10
# 3              1        119      0.462        0.394      0.769           7
# 4              1        103      0.407        0.409      0.778          12
#
#   TotalRebounds Assists Steals Blocks Turnovers TotalFouls
# 0            42      26      6      8        17         24
# 1            37      26     10      6        12         20
# 2            37      26     14      5        13         25
# 3            38      28      8      3        19         33
# 4            41      18     10      5         8         17

# %%
dataframe.columns
# Out:
# Index(['Team_Number_Id', 'TeamPoints', 'FieldGoals', 'X3PointShots',
#        'FreeThrows', 'OffRebounds', 'TotalRebounds', 'Assists', 'Steals',
#        'Blocks', 'Turnovers', 'TotalFouls'],
#       dtype='object')

# %%
dataframe['TeamPoints'].dropna(how='any')
dataframe.head(10)
# Out:
#   Team_Number_Id TeamPoints FieldGoals X3PointShots FreeThrows OffRebounds  \
# 0              1        102      0.500        0.591      0.529          10
# 1              1        102      0.507        0.350      0.758           3
# 2              1         92      0.413        0.320      0.727          10
# 3              1        119      0.462        0.394      0.769           7
# 4              1        103      0.407        0.409      0.778          12
# 5              1         91      0.380        0.370      0.964           9
# 6              1        100      0.513        0.450      0.722          13
# 7              1        114      0.560        0.393      0.826           3
# 8              1         94      0.444        0.136      0.846          11
# 9              1        109      0.482        0.333      0.783          13
#
#   TotalRebounds Assists Steals Blocks Turnovers TotalFouls
# 0            42      26      6      8        17         24
# ...

# %%
dataframe.dtypes
# Out:
# Team_Number_Id    object
# TeamPoints        object
# FieldGoals        object
# X3PointShots      object
# FreeThrows        object
# OffRebounds       object
# TotalRebounds     object
# Assists           object
# Steals            object
# Blocks            object
# Turnovers         object
# TotalFouls        object
# dtype: object

# %%
dataframe["TeamPoints"] = dataframe["TeamPoints"].astype(float)
dataframe.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fe77199269bf> in <module>
# ----> 1 dataframe["TeamPoints"] = dataframe["TeamPoints"].astype('float')
#       2 dataframe.dtypes
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...
