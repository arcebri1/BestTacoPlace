# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
from config import client_id_yelp, api_key

# %%
api_key=api_key
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'tacos','location':'San Diego', 'limit' :50}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
data = json.loads(req.text)
data
# Out:
# {'businesses': [{'id': 'uAClDzKuffu9EilZ61pP0A',
#    'alias': 'tacos-el-trompo-san-diego-2',
#    'name': 'Tacos el Trompo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4mwwULdpt5gGi49-JkmMyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-trompo-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7852176, 'longitude': -117.252822},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3819 Mission Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3819 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18583526706',
#    'display_phone': '(858) 352-6706',
#    'distance': 9249.198891924463},
#   {'id': 'DAZ6F_1zDZp3qa6X1OjuCg',
#    'alias': 'city-tacos-san-diego',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s0Z9Zic1xLzty6BXXAGsgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1940,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.74885802959357,
#     'longitude': -117.12943449824668},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3028 University Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3028 University Ave', 'San Diego, CA 92104']},
#    'phone': '+16192962303',
#    'display_phone': '(619) 296-2303',
#    'distance': 5179.104840792347},
#   {'id': 'L2Bhgxgt6CCUZuisKXbJmg',
#    'alias': 'crack-taco-shop-san-diego',
#    'name': 'CRACK Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P2q67uEJtjrE26fcBfuAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crack-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 500,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7803100019414,
#     'longitude': -117.103043161333},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4242 Camino Del Rio N',
#     'address2': 'Ste 28',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4242 Camino Del Rio N',
#      'Ste 28',
#      'San Diego, CA 92108']},
#    'phone': '+16192692828',
#    'display_phone': '(619) 269-2828',
#    'distance': 4905.809147639643},
#   {'id': 'TMPbnPfCRUv7adgOKwJ3wA',
#    'alias': 'tacos-el-panson-san-diego',
#    'name': 'Tacos El Panson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B1F0475bQcM8IVMbxVs_EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-panson-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 346,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.75486, 'longitude': -117.09907},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4433 El Cajon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4433 El Cajon Blvd', 'San Diego, CA 92115']},
#    'phone': '+16192412222',
#    'display_phone': '(619) 241-2222',
#    'distance': 6495.604013282882},
#   {'id': 'EGj92CH6mWFiRvHB1zyMAw',
#    'alias': 'lucha-libre-gourmet-taco-shop-san-diego',
#    'name': 'Lucha Libre Gourmet Taco Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/58q54BEr7a9JZFAwOoaBbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucha-libre-gourmet-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 7825,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.743229, 'longitude': -117.181628},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1810 W Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1810 W Washington St', 'San Diego, CA 92103']},
#    'phone': '+16192968226',
#    'display_phone': '(619) 296-8226',
#    'distance': 5860.274607644788},
#   {'id': 'dBtZR2CB8PVxndyF6K2wAQ',
#    'alias': 'the-taco-stand-la-jolla',
#    'name': 'The Taco Stand',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/76K7pGZt3P0ddwfrBVWyNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-taco-stand-la-jolla?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 3570,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8393664861151,
#     'longitude': -117.276808878945},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '621 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'La Jolla',
#     'zip_code': '92037',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['621 Pearl St', 'La Jolla, CA 92037']},
#    'phone': '+18585516666',
#    'display_phone': '(858) 551-6666',
#    'distance': 12687.596125558744},
#   {'id': 'B52EkpFK0GVtiJd17qokzA',
#    'alias': 'las-panchitas-fresh-mexican-grill-san-diego-2',
#    'name': 'Las Panchitas Fresh Mexican Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pDVaupHHtX6-HB9X6RXnpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-panchitas-fresh-mexican-grill-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 203,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8082291369159,
#     'longitude': -117.160630822289},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3542 Ashford St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3542 Ashford St', 'San Diego, CA 92111']},
#    'phone': '+18588746710',
#    'display_phone': '(858) 874-6710',
#    'distance': 2056.825199380479},
#   {'id': '2HZnqrM_yLDd4s9MePXYKw',
#    'alias': 'taco-time-san-diego',
#    'name': 'Taco Time',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L_wfGAy21EJKPfEMNVW8bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-time-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 20,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7831167411328,
#     'longitude': -117.172112330021},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6882 Linda Vista Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6882 Linda Vista Rd', 'San Diego, CA 92111']},
#    'phone': '+18586499807',
#    'display_phone': '(858) 649-9807',
#    'distance': 1878.0836852590753},
#   {'id': 'jjkHyoBlzNMnHJNXwyxsJQ',
#    'alias': 'the-taco-stand-san-diego-6',
#    'name': 'The Taco Stand',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dhkmGslQsBUenBaz6I0_Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-taco-stand-san-diego-6?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 422,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7411646431234,
#     'longitude': -117.129678681992},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3000 Upas St',
#     'address2': 'Ste 105',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3000 Upas St', 'Ste 105', 'San Diego, CA 92104']},
#    'phone': '+16197958797',
#    'display_phone': '(619) 795-8797',
#    'distance': 5948.623661662907},
#   {'id': '8gtS-ugNXvM90hZgqjIWiw',
#    'alias': 'lolitas-mexican-food-san-diego-5',
#    'name': "Lolita's Mexican Food",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1j_X0AKF60gCZZKPTcv2_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lolitas-mexican-food-san-diego-5?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 2452,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.832264, 'longitude': -117.160599},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7305 Clairemont Mesa Blvd',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7305 Clairemont Mesa Blvd',
#      'Ste A',
#      'San Diego, CA 92111']},
#    'phone': '+18588747983',
#    'display_phone': '(858) 874-7983',
#    'distance': 4676.0410374419325},
#   {'id': 'SdjxzqHGth-Drdxpbl5eYA',
#    'alias': 'salud-san-diego-5',
#    'name': 'Salud',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/07hMlTJvE5FWdcGFLJqkqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salud-san-diego-5?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1570,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.6981987270296,
#     'longitude': -117.13937100023},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2196 Logan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2196 Logan Ave', 'San Diego, CA 92113']},
#    'phone': '+16192553856',
#    'display_phone': '(619) 255-3856',
#    'distance': 10362.893264055758},
#   {'id': 's2xzcM6Q22gy2P3Za-X61Q',
#    'alias': 'coal-bros-taqueria-san-diego',
#    'name': 'Coal Bros Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NdQ257iZIFh3IwPQ3O37tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coal-bros-taqueria-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 86,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.71652, 'longitude': -117.16077},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '407 C St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['407 C St', 'San Diego, CA 92101']},
#    'phone': '+16194916389',
#    'display_phone': '(619) 491-6389',
#    'distance': 8250.223269626895},
#   {'id': '43BHmEbS7eBRxC7MFnqv7Q',
#    'alias': 'las-cuatro-milpas-san-diego-2',
#    'name': 'Las Cuatro Milpas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FO2K895XPJQ2JmRekZEuBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-cuatro-milpas-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 2155,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.701918, 'longitude': -117.145135},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1857 Logan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1857 Logan Ave', 'San Diego, CA 92113']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9893.033962715792},
#   {'id': 'ssJJPFuV6tTDgHYe2w9csQ',
#    'alias': 'oscars-mexican-seafood-san-diego-3',
#    'name': 'Oscars Mexican Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nmtXm16znYiTmTIP5MQdBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-mexican-seafood-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 2884,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.808189, 'longitude': -117.260846},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '703 Turquoise St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['703 Turquoise St', 'San Diego, CA 92109']},
#    'phone': '+18584886392',
#    'display_phone': '(858) 488-6392',
#    'distance': 10169.337870676562},
#   {'id': 'GZJQc4hMTibVNaS3_ksF-Q',
#    'alias': 'la-playa-taco-shop-san-diego',
#    'name': 'La Playa Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y8Ei5lv5R-Gw__J4vAa7lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-playa-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1194,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.78939, 'longitude': -117.25308},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3973 Mission Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3973 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18584887405',
#    'display_phone': '(858) 488-7405',
#    'distance': 9258.62822052106},
#   {'id': 'G490wIFt0esrvxXFvbqovQ',
#    'alias': 'tj-birrieria-san-diego',
#    'name': 'TJ Birrieria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QPJrpcTSu3yMKdloE-qmZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tj-birrieria-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 94,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.70126, 'longitude': -117.14751},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1794 Newton Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1794 Newton Ave', 'San Diego, CA 92113']},
#    'phone': '+16192551634',
#    'display_phone': '(619) 255-1634',
#    'distance': 9952.959378018339},
#   {'id': 'NFM1TlNoEz9awvfonbfNrw',
#    'alias': 'palmitos-mexican-eatery-san-diego-3',
#    'name': 'Palmitos Mexican Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8rTh_-w93AlZ-Of_SA3xrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palmitos-mexican-eatery-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 300,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8341, 'longitude': -117.1796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5145 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5145 Clairemont Mesa Blvd', 'San Diego, CA 92117']},
#    'phone': '+18589741946',
#    'display_phone': '(858) 974-1946',
#    'distance': 5402.5552959005645},
#   {'id': '19x90_yOoljPPa-KDcLsLg',
#    'alias': 'harrys-taco-club-san-diego',
#    'name': "Harry's Taco Club",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vgs01b04C8fbFbBuuQ3ukg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-taco-club-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 68,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7986742786113,
#     'longitude': -117.252488136292},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4612 Cass St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4612 Cass St', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9242.174502799093},
#   {'id': 'zCP7tTuUPkw9PeiyOp8FTw',
#    'alias': 'el-zarape-restaurant-san-diego-4',
#    'name': 'El Zarape Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yz0b5tH3IGaFblc_VicCRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-zarape-restaurant-san-diego-4?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 2651,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7618065, 'longitude': -117.146379},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4642 Park Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4642 Park Blvd', 'San Diego, CA 92116']},
#    'phone': '+16196921652',
#    'display_phone': '(619) 692-1652',
#    'distance': 3278.3885011072834},
#   {'id': 'bCDi6bD9bCISqFZ3OyDbOg',
#    'alias': 'vallarta-express-mexican-eatery-san-diego',
#    'name': 'Vallarta Express Mexican Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hfFoSPoS4KexxWQmkuqq_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vallarta-express-mexican-eatery-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1376,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.821346282959,
#     'longitude': -117.182472229004},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4277 Genesee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4277 Genesee Ave', 'San Diego, CA 92117']},
#    'phone': '+18585696945',
#    'display_phone': '(858) 569-6945',
#    'distance': 4339.998618265366},
#   {'id': 'OEuaXlUCRD3c5pOS5knIcg',
#    'alias': 'mikes-taco-club-san-diego',
#    'name': "Mike's Taco Club",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jLa8Bhyl5knv88JRssFWFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikes-taco-club-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1014,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.74765, 'longitude': -117.25199},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5060 Newport Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5060 Newport Ave', 'San Diego, CA 92107']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10327.396619847415},
#   {'id': '06lBpQZ3Ye9w7zL8j_tFPw',
#    'alias': 'tacos-el-gordo-chula-vista-6',
#    'name': 'Tacos El Gordo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bzKLq8UMLT0uuF5xxYJjbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-gordo-chula-vista-6?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 5146,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.62905, 'longitude': -117.08917},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '556 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Chula Vista',
#     'zip_code': '91910',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['556 Broadway', 'Chula Vista, CA 91910']},
#    'phone': '+16192717222',
#    'display_phone': '(619) 271-7222',
#    'distance': 18965.147084237233},
#   {'id': 'n6J_j_nUxl__kRZU9vbE6g',
#    'alias': 'taqueria-los-chuchys-san-diego',
#    'name': 'Taqueria Los Chuchys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9RlZcvufvkieopnDoyskQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-los-chuchys-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 149,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.71101, 'longitude': -117.16077},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '543 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['543 4th Ave', 'San Diego, CA 92101']},
#    'phone': '+16193268385',
#    'display_phone': '(619) 326-8385',
#    'distance': 8872.76443219748},
#   {'id': '_kWPHb4a5PAON-E2CoOluQ',
#    'alias': 'tacos-asadero-san-diego',
#    'name': 'Tacos Asadero',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XEiZm9dA19YlGmOv8UVBgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-asadero-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 174,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.00225, 'longitude': -117.059148},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '15721 Bernardo Heights Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92128',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['15721 Bernardo Heights Pkwy', 'San Diego, CA 92128']},
#    'phone': '+18585922600',
#    'display_phone': '(858) 592-2600',
#    'distance': 25153.621277075337},
#   {'id': 'whcQ3JRgfX-CJ-f3LQxDtw',
#    'alias': 'picante-taqueria-mexican-grill-san-diego-6',
#    'name': 'Picante Taqueria Mexican Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y1yVGO3csbBai9Q4K6f-Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picante-taqueria-mexican-grill-san-diego-6?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 266,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79329, 'longitude': -117.0982},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6620 Mission Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6620 Mission Gorge Rd', 'San Diego, CA 92120']},
#    'phone': '+16193589198',
#    'display_phone': '(619) 358-9198',
#    'distance': 5230.986512431691},
#   {'id': '1xNYUQqnSKcQPxN-sApuIQ',
#    'alias': 'rigobertos-taco-shop-san-diego-2',
#    'name': "Rigoberto's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6UqhhD8VxeLmS0Cvh658-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rigobertos-taco-shop-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 816,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.87994, 'longitude': -117.16208},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7094 Miramar Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7094 Miramar Rd', 'San Diego, CA 92121']},
#    'phone': '+18582710170',
#    'display_phone': '(858) 271-0170',
#    'distance': 9949.517819456574},
#   {'id': 'xsm2uqj58l8QTqHxRgbMHQ',
#    'alias': 'california-burritos-san-diego',
#    'name': 'California Burritos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5bcQ1Qb6fdzttubwi_dQiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/california-burritos-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 835,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79333, 'longitude': -117.15598},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7754 Starling Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7754 Starling Dr', 'San Diego, CA 92123']},
#    'phone': '+18585691600',
#    'display_phone': '(858) 569-1600',
#    'distance': 370.6358028129525},
#   {'id': 'S7wOVlUXorhT1LWNDBPVDw',
#    'alias': 'birrieria-la-loteria-san-diego',
#    'name': 'Birrieria La Loteria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dU7lGRkdaz1febPc8Y4Ang/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birrieria-la-loteria-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 18,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7403436, 'longitude': -117.0499749},
#    'transactions': [],
#    'location': {'address1': '6873 Federal Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '91945',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6873 Federal Blvd', 'San Diego, CA 91945']},
#    'phone': '+16193924886',
#    'display_phone': '(619) 392-4886',
#    'distance': 11222.733872399245},
#   {'id': 'yqTK2VA22GUyhFofgI40TQ',
#    'alias': 'los-panchos-san-diego-4',
#    'name': 'Los Panchos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c1Fwl6ZRUdzyXqkEHGFLsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-panchos-san-diego-4?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 188,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.76667, 'longitude': -117.18327},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6110 Friars Rd',
#     'address2': 'Ste 101',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6110 Friars Rd', 'Ste 101', 'San Diego, CA 92108']},
#    'phone': '+16192720626',
#    'display_phone': '(619) 272-0626',
#    'distance': 3808.9024235666748},
#   {'id': 'p5eu9JPW8XT__f3afPQNyQ',
#    'alias': 'kikos-place-seafood-san-diego',
#    'name': "Kiko's Place Seafood",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E3Nm0kI1E7kfVSWabdREVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikos-place-seafood-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 671,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.77402, 'longitude': -117.15447},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5494 Mission Center Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5494 Mission Center Rd', 'San Diego, CA 92108']},
#    'phone': '+16193417397',
#    'display_phone': '(619) 341-7397',
#    'distance': 1847.0613172371038},
#   {'id': 'Zc_r2V5Wb_QwryKU2ch3-A',
#    'alias': 'the-taco-stand-san-diego-3',
#    'name': 'The Taco Stand',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xpFvMI329LXYz7Bxe2yqtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-taco-stand-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 817,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.717624, 'longitude': -117.158631},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '645 B St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['645 B St', 'San Diego, CA 92101']},
#    'phone': '+16195460570',
#    'display_phone': '(619) 546-0570',
#    'distance': 8122.290292774126},
#   {'id': '33Pt6j__dIkO2nLzrj3HLw',
#    'alias': 'chuys-taco-shop-san-diego',
#    'name': "Chuy's Taco Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ob4r_a-qoGq2hbeSv0GcBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuys-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 695,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.76743, 'longitude': -117.05517},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6663 El Cajon Blvd',
#     'address2': 'Ste G',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6663 El Cajon Blvd', 'Ste G', 'San Diego, CA 92115']},
#    'phone': '+16194697777',
#    'display_phone': '(619) 469-7777',
#    'distance': 9614.38823143559},
#   {'id': 'wL7Z4NJakeQ4yz9GSWki0A',
#    'alias': 'ortizs-taco-shop-san-diego',
#    'name': "Ortiz's Taco Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QrZATKQb12Z9RhSDUCVREw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ortizs-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 597,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.74049, 'longitude': -117.22903},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3704 Voltaire St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3704 Voltaire St', 'San Diego, CA 92107']},
#    'phone': '+16192224476',
#    'display_phone': '(619) 222-4476',
#    'distance': 8943.381255509492},
#   {'id': 'c2iFpIROV9OVK3wd24J0Tw',
#    'alias': 'la-vecindad-neighborhood-tacos-san-diego-2',
#    'name': 'La Vecindad Neighborhood Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cm9oF29wlGv5Z3QaeYoUZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vecindad-neighborhood-tacos-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 998,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7476563, 'longitude': -117.1602513},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3827 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3827 5th Ave', 'San Diego, CA 92103']},
#    'phone': '+16195012885',
#    'display_phone': '(619) 501-2885',
#    'distance': 4819.13577936874},
#   {'id': 'iGkLE8G0m2OBZXgOxqQm7w',
#    'alias': 'oscars-mexican-seafood-san-diego-6',
#    'name': 'Oscars Mexican Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nWpy5z9l3F3jEyA4WpTNlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-mexican-seafood-san-diego-6?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1612,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7486014556313,
#     'longitude': -117.15913947605},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '646 University Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['646 University Ave', 'San Diego, CA 92103']},
#    'phone': '+16192305560',
#    'display_phone': '(619) 230-5560',
#    'distance': 4690.501461499774},
#   {'id': '8caDxhRrzu10eDmQACpMDA',
#    'alias': 'tacos-el-cabrón-san-diego-3',
#    'name': 'Tacos El Cabrón',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/15P9mQFQOczpwlirALs-OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-cabr%C3%B3n-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 399,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.710719456919,
#     'longitude': -117.161089675616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '532 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['532 4th Ave', 'San Diego, CA 92101']},
#    'phone': '+16195017752',
#    'display_phone': '(619) 501-7752',
#    'distance': 8903.042066508553},
#   {'id': 'J0GLFRE_rcgrVp4K0joTsg',
#    'alias': 'tacos-el-gordo-san-diego',
#    'name': 'Tacos El Gordo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FaWIkPY_CIGwjMAz_6qbjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-gordo-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 957,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.58347, 'longitude': -117.06294},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3265 Palm Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92154',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3265 Palm Ave', 'San Diego, CA 92154']},
#    'phone': '+16195757280',
#    'display_phone': '(619) 575-7280',
#    'distance': 24548.76794321491},
#   {'id': 'WsY64p6s4BG4wKeJaR0iyg',
#    'alias': 'el-patron-traditional-mexican-grill-san-diego',
#    'name': 'El Patron Traditional Mexican Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/49l1CkNJc40UJ27-a5HuBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-patron-traditional-mexican-grill-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 1187,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9174449, 'longitude': -117.1210759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9460 Mira Mesa Blvd',
#     'address2': 'Ste H',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92126',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9460 Mira Mesa Blvd',
#      'Ste H',
#      'San Diego, CA 92126']},
#    'phone': '+18585493467',
#    'display_phone': '(858) 549-3467',
#    'distance': 14620.370618064648},
#   {'id': 'cexxLL6wmxZGuBXGgKK-8Q',
#    'alias': 'el-gordo-mexican-food-san-diego-3',
#    'name': 'El Gordo Mexican Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vZlS-l-EC4kPDiGwhpKPzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-gordo-mexican-food-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 21,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.82836855006261, 'longitude': -117.1537959},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4768 Convoy St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4768 Convoy St', 'San Diego, CA 92111']},
#    'phone': '+18582216530',
#    'display_phone': '(858) 221-6530',
#    'distance': 4203.155456466992},
#   {'id': 'kdjSNl1ciYCqWsa0qC6l1w',
#    'alias': 'la-tiendita-de-linda-vista-san-diego-2',
#    'name': 'La Tiendita De Linda Vista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rlRdc1KWXRPtd1r-dD4Tgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tiendita-de-linda-vista-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 82,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7837, 'longitude': -117.16926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2187 Ulric St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2187 Ulric St', 'San Diego, CA 92111']},
#    'phone': '+18585656469',
#    'display_phone': '(858) 565-6469',
#    'distance': 1612.925974837034},
#   {'id': 'iVWC7ivyOVNJsnxSreMopg',
#    'alias': 'la-palapa-taco-shop-san-diego',
#    'name': 'La Palapa Taco Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOLRZe9i1H3elinbAxbhkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-palapa-taco-shop-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 41,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.823277, 'longitude': -117.214099},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4386 Moraga Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4386 Moraga Ave', 'San Diego, CA 92117']},
#    'phone': '+18584901190',
#    'display_phone': '(858) 490-1190',
#    'distance': 6687.746793171172},
#   {'id': 'e8I1GAJgBdl2f8KksYCVNg',
#    'alias': 'fit-tacos-san-diego-3',
#    'name': 'Fit Tacos ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/41SzlP8snleUCnR44eZiyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fit-tacos-san-diego-3?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 32,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.8338314, 'longitude': -117.1462858},
#    'transactions': [],
#    'location': {'address1': '8262 Clairemont Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8262 Clairemont Blvd', 'San Diego, CA 92111']},
#    'phone': '+16196130266',
#    'display_phone': '(619) 613-0266',
#    'distance': 4865.38942188495},
#   {'id': 'ByT2w8djGeGYrVG1eBnb9w',
#    'alias': 'mariscos-mi-gusto-es-san-diego-2',
#    'name': 'Mariscos Mi Gusto Es',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z5kX9QPkiGXUux-PjQqvyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mariscos-mi-gusto-es-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 266,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.729069, 'longitude': -117.098941},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4425 Home Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92105',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4425 Home Ave', 'San Diego, CA 92105']},
#    'phone': '+16192745924',
#    'display_phone': '(619) 274-5924',
#    'distance': 8561.012879186888},
#   {'id': 'SNYMxDXzG6W8drNVLenmKA',
#    'alias': 'el-tianguis-san-diego',
#    'name': 'El Tianguis',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GzX9cK8MDJzfrpmWXTw6fQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-tianguis-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 325,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7557, 'longitude': -117.13346},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2810 El Cajon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2810 El Cajon Blvd', 'San Diego, CA 92104']},
#    'phone': '+16196773581',
#    'display_phone': '(619) 677-3581',
#    'distance': 4324.41953287124},
#   {'id': 'GUt47DeMiHd_jBNm1sLjOA',
#    'alias': 'tacos-el-g-national-city-7',
#    'name': 'Tacos El G',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/koGCUWWlcH473W7g6-C8Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-g-national-city-7?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 934,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.66789, 'longitude': -117.09507},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1940 Highland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'National City',
#     'zip_code': '91950',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1940 Highland Ave', 'National City, CA 91950']},
#    'phone': '+16194745033',
#    'display_phone': '(619) 474-5033',
#    'distance': 14733.650706001392},
#   {'id': '7ynGOTsVyp_62wQgzCFY8w',
#    'alias': 'calis-and-fries-san-diego',
#    'name': "Cali's & Fries",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jYHj1aAbuJP47Hm8ylAi_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calis-and-fries-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 127,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8317489624023,
#     'longitude': -117.121040344238},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5150 Murphy Canyon Rd',
#     'address2': 'Ste 109',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5150 Murphy Canyon Rd',
#      'Ste 109',
#      'San Diego, CA 92123']},
#    'phone': '+18582797733',
#    'display_phone': '(858) 279-7733',
#    'distance': 5484.046954169857},
#   {'id': 'uqBl_FBwUA3koLg2GGClLg',
#    'alias': 'la-fachada-san-diego',
#    'name': 'La Fachada',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YDYL0IFVia8OuXsnTFEVJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fachada-san-diego?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 618,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7055101032875,
#     'longitude': -117.140484931802},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '20 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['20 25th St', 'San Diego, CA 92102']},
#    'phone': '+16192368566',
#    'display_phone': '(619) 236-8566',
#    'distance': 9543.265892355725},
#   {'id': 'vnO2BKUv3c40Lw-eOAiLWQ',
#    'alias': 'tacos-el-gordo-san-diego-2',
#    'name': 'Tacos El Gordo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uxJLRXHuqfDZErXqe-8DQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-gordo-san-diego-2?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 128,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 32.7913799, 'longitude': -117.25501},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '711 Oliver Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['711 Oliver Ave', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9437.425854782678},
#   {'id': '0h9sxN8o3BZqMywX7QSwqQ',
#    'alias': 'humbertos-taco-shop-san-diego-5',
#    'name': "Humberto's Taco Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_P8HCCWLqG3h6MNV3hWSSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/humbertos-taco-shop-san-diego-5?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 703,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7159770730254,
#     'longitude': -117.139981814592},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1015 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1015 25th St', 'San Diego, CA 92102']},
#    'phone': '+16192318433',
#    'display_phone': '(619) 231-8433',
#    'distance': 8398.454721485534},
#   {'id': 'uIw0cAlaZY-Hans7qr3ztQ',
#    'alias': 'el-cabrón-lemon-grove',
#    'name': 'El Cabrón',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GQFFljtPWYwm0HnY-CvtMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-cabr%C3%B3n-lemon-grove?adjust_creative=MWxVGaN-wwQ0ihWaIfhrqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MWxVGaN-wwQ0ihWaIfhrqQ',
#    'review_count': 7,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.742029775122376,
#     'longitude': -117.04926788806917},
#    'transactions': [],
#    'location': {'address1': '6966 Federal Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Lemon Grove',
#     'zip_code': '91945',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6966 Federal Blvd', 'Lemon Grove, CA 91945']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11188.398166234883}],
#  'total': 3800,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}

# %% [markdown]
# ## Save file

# %%
with open('yelpTacosLoc.json', 'w') as json_file:
    json.dump(data, json_file)
