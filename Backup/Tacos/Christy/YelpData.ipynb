# %%
import pandas, requests
import json
import requests
from config import api_key

# %%
api_key=api_key
headers ={'Authorization': 'Bearer %s' % api_key}

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'Mexican', 'location': 'San Diego', 'categories': 'tacos', 'limit':50}

# %%
req = requests.get(url, params=params, headers=headers)

print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
data =json.loads(req.text)
data
# Out:
# {'businesses': [{'id': 'L2Bhgxgt6CCUZuisKXbJmg',
#    'alias': 'crack-taco-shop-san-diego',
#    'name': 'CRACK Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P2q67uEJtjrE26fcBfuAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crack-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 500,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7803100019414,
#     'longitude': -117.103043161333},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4242 Camino Del Rio N',
#     'address2': 'Ste 28',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4242 Camino Del Rio N',
#      'Ste 28',
#      'San Diego, CA 92108']},
#    'phone': '+16192692828',
#    'display_phone': '(619) 269-2828',
#    'distance': 4905.809147639643},
#   {'id': 'whcQ3JRgfX-CJ-f3LQxDtw',
#    'alias': 'picante-taqueria-mexican-grill-san-diego-6',
#    'name': 'Picante Taqueria Mexican Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y1yVGO3csbBai9Q4K6f-Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picante-taqueria-mexican-grill-san-diego-6?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 266,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79329, 'longitude': -117.0982},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6620 Mission Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6620 Mission Gorge Rd', 'San Diego, CA 92120']},
#    'phone': '+16193589198',
#    'display_phone': '(619) 358-9198',
#    'distance': 5230.986512431691},
#   {'id': '7ynGOTsVyp_62wQgzCFY8w',
#    'alias': 'calis-and-fries-san-diego',
#    'name': "Cali's & Fries",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jYHj1aAbuJP47Hm8ylAi_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calis-and-fries-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 127,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8317489624023,
#     'longitude': -117.121040344238},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5150 Murphy Canyon Rd',
#     'address2': 'Ste 109',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5150 Murphy Canyon Rd',
#      'Ste 109',
#      'San Diego, CA 92123']},
#    'phone': '+18582797733',
#    'display_phone': '(858) 279-7733',
#    'distance': 5484.046954169857},
#   {'id': '1xNYUQqnSKcQPxN-sApuIQ',
#    'alias': 'rigobertos-taco-shop-san-diego-2',
#    'name': "Rigoberto's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6UqhhD8VxeLmS0Cvh658-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rigobertos-taco-shop-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 816,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.87994, 'longitude': -117.16208},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7094 Miramar Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7094 Miramar Rd', 'San Diego, CA 92121']},
#    'phone': '+18582710170',
#    'display_phone': '(858) 271-0170',
#    'distance': 9949.517819456574},
#   {'id': 'c2iFpIROV9OVK3wd24J0Tw',
#    'alias': 'la-vecindad-neighborhood-tacos-san-diego-2',
#    'name': 'La Vecindad Neighborhood Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cm9oF29wlGv5Z3QaeYoUZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vecindad-neighborhood-tacos-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 998,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7476563, 'longitude': -117.1602513},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3827 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3827 5th Ave', 'San Diego, CA 92103']},
#    'phone': '+16195012885',
#    'display_phone': '(619) 501-2885',
#    'distance': 4819.13577936874},
#   {'id': 'GZJQc4hMTibVNaS3_ksF-Q',
#    'alias': 'la-playa-taco-shop-san-diego',
#    'name': 'La Playa Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y8Ei5lv5R-Gw__J4vAa7lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-playa-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1194,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.78939, 'longitude': -117.25308},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3973 Mission Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3973 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18584887405',
#    'display_phone': '(858) 488-7405',
#    'distance': 9258.62822052106},
#   {'id': 'DAZ6F_1zDZp3qa6X1OjuCg',
#    'alias': 'city-tacos-san-diego',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s0Z9Zic1xLzty6BXXAGsgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1940,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.74885802959357,
#     'longitude': -117.12943449824668},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3028 University Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3028 University Ave', 'San Diego, CA 92104']},
#    'phone': '+16192962303',
#    'display_phone': '(619) 296-2303',
#    'distance': 5179.104840792347},
#   {'id': 'TMPbnPfCRUv7adgOKwJ3wA',
#    'alias': 'tacos-el-panson-san-diego',
#    'name': 'Tacos El Panson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B1F0475bQcM8IVMbxVs_EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-panson-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 346,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.75486, 'longitude': -117.09907},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4433 El Cajon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4433 El Cajon Blvd', 'San Diego, CA 92115']},
#    'phone': '+16192412222',
#    'display_phone': '(619) 241-2222',
#    'distance': 6495.604013282882},
#   {'id': 'iVWC7ivyOVNJsnxSreMopg',
#    'alias': 'la-palapa-taco-shop-san-diego',
#    'name': 'La Palapa Taco Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOLRZe9i1H3elinbAxbhkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-palapa-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 41,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.823277, 'longitude': -117.214099},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4386 Moraga Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4386 Moraga Ave', 'San Diego, CA 92117']},
#    'phone': '+18584901190',
#    'display_phone': '(858) 490-1190',
#    'distance': 6687.746793171172},
#   {'id': 'OAnJnRs9-w5rtSK3TBxH3A',
#    'alias': 'trujillos-taco-shop-san-diego-4',
#    'name': "Trujillo's Taco Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B0RPwK9V-zy1rVNFxL-a6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trujillos-taco-shop-san-diego-4?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 125,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.76608, 'longitude': -117.06045},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6450 El Cajon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6450 El Cajon Blvd', 'San Diego, CA 92115']},
#    'phone': '+16195821451',
#    'display_phone': '(619) 582-1451',
#    'distance': 9169.43379785958},
#   {'id': 'calNCZE_Ub2W4TXcSoaeTg',
#    'alias': 'baja-bay-grill-san-diego',
#    'name': 'Baja Bay Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lW6y-aJZAwlYCqwz76_wsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baja-bay-grill-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 46,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7956947629753,
#     'longitude': -117.251699902117},
#    'transactions': [],
#    'location': {'address1': '980 Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['980 Grand Ave', 'San Diego, CA 92109']},
#    'phone': '+18588867927',
#    'display_phone': '(858) 886-7927',
#    'distance': 9142.385375391443},
#   {'id': 'n6J_j_nUxl__kRZU9vbE6g',
#    'alias': 'taqueria-los-chuchys-san-diego',
#    'name': 'Taqueria Los Chuchys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9RlZcvufvkieopnDoyskQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-los-chuchys-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 149,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.71101, 'longitude': -117.16077},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '543 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['543 4th Ave', 'San Diego, CA 92101']},
#    'phone': '+16193268385',
#    'display_phone': '(619) 326-8385',
#    'distance': 8872.76443219748},
#   {'id': '9b7KyVavhVS9LDu6OADgJw',
#    'alias': 'don-roman-san-diego-2',
#    'name': 'Don Roman',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NTRxdbLBBkEgK0UMQwzxoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-roman-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 110,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.760822, 'longitude': -117.065737},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6145 El Cajon Blvd',
#     'address2': 'Ste J',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6145 El Cajon Blvd', 'Ste J', 'San Diego, CA 92115']},
#    'phone': '+16196420800',
#    'display_phone': '(619) 642-0800',
#    'distance': 8888.11726059812},
#   {'id': 's2xzcM6Q22gy2P3Za-X61Q',
#    'alias': 'coal-bros-taqueria-san-diego',
#    'name': 'Coal Bros Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NdQ257iZIFh3IwPQ3O37tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coal-bros-taqueria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 86,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.71652, 'longitude': -117.16077},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '407 C St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['407 C St', 'San Diego, CA 92101']},
#    'phone': '+16194916389',
#    'display_phone': '(619) 491-6389',
#    'distance': 8250.223269626895},
#   {'id': 'uUTp1QA34_NBiixhfH6SfQ',
#    'alias': 'tbs-tavern-san-diego',
#    'name': 'TBS Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_og18Fw20roEhO9pvxqxYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tbs-tavern-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 56,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.773961, 'longitude': -117.142537791842},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8555 Station Village Way',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8555 Station Village Way', 'San Diego, CA 92108']},
#    'phone': '+16193594198',
#    'display_phone': '(619) 359-4198',
#    'distance': 2139.042631210627},
#   {'id': '_gpPJXtcxwpRRSJjQ8Erow',
#    'alias': 'el-rodeo-taco-shop-san-diego',
#    'name': 'El Rodeo Taco Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/os5gF3rBL1h_K1wurb1I1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rodeo-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 254,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7914183, 'longitude': -117.08195},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5149 Waring Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5149 Waring Rd', 'San Diego, CA 92120']},
#    'phone': '+16192291840',
#    'display_phone': '(619) 229-1840',
#    'distance': 6743.396009529592},
#   {'id': 'jxVkC6R-pFiH7LjYwplGfA',
#    'alias': 'burros-and-fries-san-diego-7',
#    'name': 'Burros & Fries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bWZwNsd6Cdl3a0CdQ8_ODQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burros-and-fries-san-diego-7?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 99,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.8310215849872,
#     'longitude': -117.130342068733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9211 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9211 Clairemont Mesa Blvd', 'San Diego, CA 92123']},
#    'phone': '+18588361277',
#    'display_phone': '(858) 836-1277',
#    'distance': 5015.522570457526},
#   {'id': 'bXJxSKWlmisvsiiZ0XueUQ',
#    'alias': 'medina-moroccan-baja-kitchen-san-diego',
#    'name': 'Medina Moroccan-Baja Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1N3VhP8Y9IpKBewMW8OU6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/medina-moroccan-baja-kitchen-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 197,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7555903, 'longitude': -117.1323809},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2850 El Cajon Blvd',
#     'address2': 'Ste 4',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2850 El Cajon Blvd', 'Ste 4', 'San Diego, CA 92104']},
#    'phone': '+16192305037',
#    'display_phone': '(619) 230-5037',
#    'distance': 4386.9401150913645},
#   {'id': 'nae47HC_0iTel79nKRV3SA',
#    'alias': 'humbertos-taco-shop-san-diego-3',
#    'name': "Humberto's Taco Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7R4gPffAFXGvGkaqxIc3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/humbertos-taco-shop-san-diego-3?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 260,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.69429, 'longitude': -117.10266},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1136 S 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1136 S 43rd St', 'San Diego, CA 92113']},
#    'phone': '+16192668433',
#    'display_phone': '(619) 266-8433',
#    'distance': 11738.734034104922},
#   {'id': 'tMxgORlnyro6R7gUpohpkA',
#    'alias': 'stars-and-stripes-taco-shop-san-diego',
#    'name': 'Stars & Stripes Travel Center',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UKj8BhWTcA59t5t_P3XH7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stars-and-stripes-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 117,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.877183, 'longitude': -117.186113},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5706 Miramar Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5706 Miramar Rd', 'San Diego, CA 92121']},
#    'phone': '+18584509776',
#    'display_phone': '(858) 450-9776',
#    'distance': 10085.202588777967},
#   {'id': 'KWIHJu11t2llkyGo7RxATg',
#    'alias': 'taco-surf-pacific-beach-san-diego',
#    'name': 'Taco Surf Pacific Beach',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ja43BUUla6QK_K6xDfknvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-surf-pacific-beach-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1004,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79876, 'longitude': -117.25585},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4657 Mission Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4657 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18582723877',
#    'display_phone': '(858) 272-3877',
#    'distance': 9572.447426149554},
#   {'id': 'RkuubU30kfYr-NzHM4BGfg',
#    'alias': 'south-beach-bar-and-grille-san-diego',
#    'name': 'South Beach Bar & Grille',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/diBbk_ll_DwXSSOe_1G9pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-beach-bar-and-grille-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 2738,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.74729, 'longitude': -117.2523},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5059 Newport Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5059 Newport Ave', 'San Diego, CA 92107']},
#    'phone': '+16192264577',
#    'display_phone': '(619) 226-4577',
#    'distance': 10381.227435856203},
#   {'id': 'Dn0c3hCvCHYPY4zPGQ2N7w',
#    'alias': 'not-not-tacos-san-diego',
#    'name': 'Not Not Tacos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OfFEgW_nR7D5_yhEyosI_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/not-not-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 311,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.723171, 'longitude': -117.167677},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '550 W Date St',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['550 W Date St', 'Ste B', 'San Diego, CA 92101']},
#    'phone': '+16192696725',
#    'display_phone': '(619) 269-6725',
#    'distance': 7601.394162934105},
#   {'id': 'gIuxWaIu2M3JlzYAPLX0bA',
#    'alias': 'taqueria-pepitos-santee',
#    'name': 'Taqueria Pepitos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Rfdl9QQOZ6iAnCdI5PK-PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-pepitos-santee?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 116,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.832895, 'longitude': -117.000421},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '8667 Fanita Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Santee',
#     'zip_code': '92071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8667 Fanita Dr', 'Santee, CA 92071']},
#    'phone': '+16195021171',
#    'display_phone': '(619) 502-1171',
#    'distance': 15103.045765244462},
#   {'id': 'a6yxQHge4tcaKGV2lt4U3A',
#    'alias': 'tuetano-taqueria-san-diego',
#    'name': 'Tuetano Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E6_C-6q1U5qw8ijVkh5blA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuetano-taqueria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 237,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.55324, 'longitude': -117.0459},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '143 W San Ysidro Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92173',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['143 W San Ysidro Blvd', 'San Diego, CA 92173']},
#    'phone': '+16198567013',
#    'display_phone': '(619) 856-7013',
#    'distance': 28272.040549042926},
#   {'id': '19x90_yOoljPPa-KDcLsLg',
#    'alias': 'harrys-taco-club-san-diego',
#    'name': "Harry's Taco Club",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vgs01b04C8fbFbBuuQ3ukg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-taco-club-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 68,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7986742786113,
#     'longitude': -117.252488136292},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4612 Cass St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4612 Cass St', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9242.174502799093},
#   {'id': 'pxnJu_rJoPFaoEbvoPCl2A',
#    'alias': 'coastal-cantina-san-diego',
#    'name': 'Coastal Cantina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HrRlrkOILXNW6sRC8T1tDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coastal-cantina-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 30,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.71447, 'longitude': -117.16045},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '431 E St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['431 E St', 'San Diego, CA 92101']},
#    'phone': '+16199156349',
#    'display_phone': '(619) 915-6349',
#    'distance': 8485.402330633437},
#   {'id': 'S7wOVlUXorhT1LWNDBPVDw',
#    'alias': 'birrieria-la-loteria-san-diego',
#    'name': 'Birrieria La Loteria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dU7lGRkdaz1febPc8Y4Ang/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birrieria-la-loteria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 18,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7403436, 'longitude': -117.0499749},
#    'transactions': [],
#    'location': {'address1': '6873 Federal Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '91945',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6873 Federal Blvd', 'San Diego, CA 91945']},
#    'phone': '+16193924886',
#    'display_phone': '(619) 392-4886',
#    'distance': 11222.733872399245},
#   {'id': 'fSN6srCjgfj3KBDpSHn30w',
#    'alias': 'el-jefe-san-diego',
#    'name': 'El Jefe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PLEawKHw-1YFenRVVHHfjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-jefe-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 5,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.770047, 'longitude': -117.252631},
#    'transactions': [],
#    'location': {'address1': '3105 Ocean Front Walk',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3105 Ocean Front Walk', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9493.386585559841},
#   {'id': 'k5iA70JBHhY8ucLXGR0npA',
#    'alias': 'el-charro-taco-shop-san-diego-2',
#    'name': 'El Charro Taco Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uoiQ8yu9yVwtw3OoRakF0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-charro-taco-shop-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 75,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7505499, 'longitude': -117.21332},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3445 Midway Dr',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3445 Midway Dr', 'Ste B', 'San Diego, CA 92110']},
#    'phone': '+16192240774',
#    'display_phone': '(619) 224-0774',
#    'distance': 7115.500415585015},
#   {'id': 'vWUDpdnaWrAVdA_5IRMtxQ',
#    'alias': 'casa-de-freds-tacos-y-tequila-san-diego',
#    'name': 'Casa de Freds Tacos y Tequila',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mON6zhLyWG23an--qOtz7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-de-freds-tacos-y-tequila-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1676,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.7526343, 'longitude': -117.1940694},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2470 San Diego Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2470 San Diego Ave', 'San Diego, CA 92110']},
#    'phone': '+16198588226',
#    'display_phone': '(619) 858-8226',
#    'distance': 5636.48370200403},
#   {'id': 'Fe6PVV6jbl2WVjdfIwdZHw',
#    'alias': 'areli-s-taco-shop-san-diego',
#    'name': 'Areli’s Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PI_drAgmy2mS4pziNvTkkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/areli-s-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 8,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.798341, 'longitude': -117.245803},
#    'transactions': [],
#    'location': {'address1': '1313 Garnet Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1313 Garnet Ave', 'San Diego, CA 92109']},
#    'phone': '+18582748931',
#    'display_phone': '(858) 274-8931',
#    'distance': 8617.374734241515},
#   {'id': 'runGViQ9mHIh5iSfcx-Eig',
#    'alias': 'mr-birria-santee-2',
#    'name': 'Mr Birria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rkegp4f5xiQb4JJ4or3edw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-birria-santee-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 98,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.83953, 'longitude': -116.99629},
#    'transactions': [],
#    'location': {'address1': '8926 Carlton Hills Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Santee',
#     'zip_code': '92071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8926 Carlton Hills Blvd', 'Santee, CA 92071']},
#    'phone': '+16193280058',
#    'display_phone': '(619) 328-0058',
#    'distance': 15714.023738733664},
#   {'id': '6utCiXqnaY5PfcmwDlRqcw',
#    'alias': 'city-tacos-san-diego-4',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jggqyoEyayIptuGpB9Bp7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego-4?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 41,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.904407, 'longitude': -117.22788},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11045 Roselle St',
#     'address2': 'Ste 100',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['11045 Roselle St', 'Ste 100', 'San Diego, CA 92121']},
#    'phone': '+18582175374',
#    'display_phone': '(858) 217-5374',
#    'distance': 14409.437718360752},
#   {'id': 'DNtaym0EPp3Y8S3B7Sn82Q',
#    'alias': 'la-taqueria-tijuana-san-diego',
#    'name': 'La Taqueria Tijuana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HcF_SaSxxuWlEeFJTrmQkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-taqueria-tijuana-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 44,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.58351, 'longitude': -117.09582},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1753 Palm Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92153',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1753 Palm Ave', 'San Diego, CA 92153']},
#    'phone': '+16193139127',
#    'display_phone': '(619) 313-9127',
#    'distance': 23666.719090833034},
#   {'id': 'vfH0YVtRs4g1ykpb6Fnp_w',
#    'alias': 'raymundo-s-taco-shop-la-jolla',
#    'name': 'Raymundo’s Taco Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1H4uORpKqxmqVyhzsIC2NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raymundo-s-taco-shop-la-jolla?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 9,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.847568, 'longitude': -117.272435},
#    'transactions': [],
#    'location': {'address1': '7918 Ivanhoe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'La Jolla',
#     'zip_code': '92037',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7918 Ivanhoe Ave', 'La Jolla, CA 92037']},
#    'phone': '+18583526867',
#    'display_phone': '(858) 352-6867',
#    'distance': 12752.17856829004},
#   {'id': 'pFwm-rdUE17jeObSsQMRHg',
#    'alias': 'toritos-mexican-grill-san-diego',
#    'name': 'Toritos Mexican Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fCCtwMKMk32syYr6q_SrFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toritos-mexican-grill-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 36,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.584831, 'longitude': -117.0390434},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4370 Palm Ave',
#     'address2': 'Ste E',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92154',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4370 Palm Ave', 'Ste E', 'San Diego, CA 92154']},
#    'phone': '+16199476005',
#    'display_phone': '(619) 947-6005',
#    'distance': 25283.677491546805},
#   {'id': 'lfOv3T15_aeSLydomYD22w',
#    'alias': 'ruribertos-taco-shop-san-diego',
#    'name': "Ruriberto's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oJdos6olwWAQTWyeXQM6RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruribertos-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 356,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.77221, 'longitude': -117.25141},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3202 Mission Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3202 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18584881610',
#    'display_phone': '(858) 488-1610',
#    'distance': 9327.301267862566},
#   {'id': 'ZYaOk1IY_6TpgW0e4wW2Iw',
#    'alias': 'tacos-el-gallo-el-cajon',
#    'name': 'Tacos El Gallo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m3LUArAQ8rdBGp7WcLxsYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-gallo-el-cajon?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 65,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.801604, 'longitude': -116.935444},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '569 N 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'El Cajon',
#     'zip_code': '92021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['569 N 2nd St', 'El Cajon, CA 92021']},
#    'phone': '+16194995500',
#    'display_phone': '(619) 499-5500',
#    'distance': 20476.564819535284},
#   {'id': '-ztxa5dsVmIYp49d2dsg2A',
#    'alias': 'tacos-and-gorditas-san-diego',
#    'name': 'Tacos and Gorditas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Utd0LA-zml7ytmUAam-lfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-and-gorditas-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 203,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.5967198, 'longitude': -116.9028125},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2445 Otay Center Dr',
#     'address2': 'Ste 112',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92154',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2445 Otay Center Dr',
#      'Ste 112',
#      'San Diego, CA 92154']},
#    'phone': '+16197583794',
#    'display_phone': '(619) 758-3794',
#    'distance': 31898.331738325523},
#   {'id': 'yDcOrQW2aQZs8aN323-yIw',
#    'alias': 'rolandos-taco-shop-san-diego-11',
#    'name': "Rolando's Taco Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ZNaeVk6ZMNyTeT4NfB7CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rolandos-taco-shop-san-diego-11?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 93,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.7837175, 'longitude': -117.098186},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6030 Mission Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6030 Mission Gorge Rd', 'San Diego, CA 92120']},
#    'phone': '+16192835369',
#    'display_phone': '(619) 283-5369',
#    'distance': 5258.5465934165195},
#   {'id': 'IEafp8ghEvcZxUKl4SAvZg',
#    'alias': 'habanero-street-tacos-san-diego',
#    'name': 'Habanero Street Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pQz_FSW2Jw3--C98TZTg8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habanero-street-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 21,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7613133, 'longitude': -117.1258361},
#    'transactions': [],
#    'location': {'address1': '4607 Iowa St',
#     'address2': 'Ste 4',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4607 Iowa St', 'Ste 4', 'San Diego, CA 92116']},
#    'phone': '+17204019680',
#    'display_phone': '(720) 401-9680',
#    'distance': 4190.116510808968},
#   {'id': 'lufX3zagRcN8yHCGh_xagA',
#    'alias': 'city-tacos-la-mesa-2',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ez2kLI-E0NaiERWhroARWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-la-mesa-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 673,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7650642806573,
#     'longitude': -117.018342186508},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8325 La Mesa Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'La Mesa',
#     'zip_code': '91942',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8325 La Mesa Blvd', 'La Mesa, CA 91942']},
#    'phone': '+16194677999',
#    'display_phone': '(619) 467-7999',
#    'distance': 13003.460242020055},
#   {'id': 'LgnhE7hbMA2BR4DBkUSLSw',
#    'alias': 'rodrigos-taco-shop-san-diego',
#    'name': "Rodrigo's Taco Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yFrrRhtgZMUhjLKeCnj9iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodrigos-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 247,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9611601081819,
#     'longitude': -117.113958641849},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9926 Carmel Mountain Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92129',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9926 Carmel Mountain Rd', 'San Diego, CA 92129']},
#    'phone': '+18585382067',
#    'display_phone': '(858) 538-2067',
#    'distance': 19335.36158085786},
#   {'id': 'UPbnh-gStJbgCmqxzwv8WA',
#    'alias': 'chula-tacos-san-diego',
#    'name': 'Chula Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JLhavNGcCwfi6Uf37hIPVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chula-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 32,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7112269, 'longitude': -117.1020353},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4301 Market St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4301 Market St', 'San Diego, CA 92102']},
#    'phone': '+16194512517',
#    'display_phone': '(619) 451-2517',
#    'distance': 10076.106246810241},
#   {'id': 'doiIEXqFp0Txa_40xFotMQ',
#    'alias': 'robertos-taco-shop-san-diego-28',
#    'name': "Roberto's Taco Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IIcroqZRF7q78yIZyd95jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertos-taco-shop-san-diego-28?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 249,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.74977, 'longitude': -117.24246},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4770 Voltaire St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4770 Voltaire St', 'San Diego, CA 92107']},
#    'phone': '+16195231162',
#    'display_phone': '(619) 523-1162',
#    'distance': 9422.040485020727},
#   {'id': 'nD1yxnwQIfcFlf0ex6FGlg',
#    'alias': 'city-tacos-san-diego-5',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3drOO9a-K9hZ0BnLen4DZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego-5?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 55,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.796612400000356,
#     'longitude': -117.25591870000143},
#    'transactions': ['delivery'],
#    'location': {'address1': '4516 Mission Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4516 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18582844239',
#    'display_phone': '(858) 284-4239',
#    'distance': 9542.590129274426},
#   {'id': '0mOdEBn9EyeOYDfOXs2p7w',
#    'alias': 'taqueria-revolucion-chula-vista',
#    'name': 'Taqueria Revolucion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fdeif5HjiWYzko-KVMqqUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-revolucion-chula-vista?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 769,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.6482277704582,
#     'longitude': -117.059008531739},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3001 Bonita Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chula Vista',
#     'zip_code': '91910',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3001 Bonita Rd', 'Chula Vista, CA 91910']},
#    'phone': '+16199349191',
#    'display_phone': '(619) 934-9191',
#    'distance': 18155.55143412463},
#   {'id': 'YzPKpl5mRNYFlVm16PItsQ',
#    'alias': 'karinas-cantina-la-jolla',
#    'name': "Karina's Cantina",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P-BNB-UPTUmEsW13AydFCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karinas-cantina-la-jolla?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 29,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.84259, 'longitude': -117.27186},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1055 Torrey Pines Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'La Jolla',
#     'zip_code': '92037',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1055 Torrey Pines Rd', 'La Jolla, CA 92037']},
#    'phone': '+18589990744',
#    'display_phone': '(858) 999-0744',
#    'distance': 12438.844612643088},
#   {'id': 'c-dMCoJgUAtp6YcdJy1RGA',
#    'alias': 'el-rey-tacos-a-vapor-san-diego',
#    'name': 'El Rey Tacos a Vapor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dUdYyUR1kIsAl37CPXovZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rey-tacos-a-vapor-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 3,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.75572833, 'longitude': -117.14226667},
#    'transactions': [],
#    'location': {'address1': '2104 El Cajon Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2104 El Cajon Blvd', 'San Diego, CA 92104']},
#    'phone': '+16194542953',
#    'display_phone': '(619) 454-2953',
#    'distance': 4025.8768080007208}],
#  'total': 500,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}

# %%
# json.loads(req.text)
# Out:
# {'businesses': [{'id': 'L2Bhgxgt6CCUZuisKXbJmg',
#    'alias': 'crack-taco-shop-san-diego',
#    'name': 'CRACK Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P2q67uEJtjrE26fcBfuAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crack-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 500,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7803100019414,
#     'longitude': -117.103043161333},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4242 Camino Del Rio N',
#     'address2': 'Ste 28',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4242 Camino Del Rio N',
#      'Ste 28',
#      'San Diego, CA 92108']},
#    'phone': '+16192692828',
#    'display_phone': '(619) 269-2828',
#    'distance': 4905.809147639643},
#   {'id': 'whcQ3JRgfX-CJ-f3LQxDtw',
#    'alias': 'picante-taqueria-mexican-grill-san-diego-6',
#    'name': 'Picante Taqueria Mexican Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y1yVGO3csbBai9Q4K6f-Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picante-taqueria-mexican-grill-san-diego-6?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 266,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79329, 'longitude': -117.0982},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '6620 Mission Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6620 Mission Gorge Rd', 'San Diego, CA 92120']},
#    'phone': '+16193589198',
#    'display_phone': '(619) 358-9198',
#    'distance': 5230.986512431691},
#   {'id': '7ynGOTsVyp_62wQgzCFY8w',
#    'alias': 'calis-and-fries-san-diego',
#    'name': "Cali's & Fries",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jYHj1aAbuJP47Hm8ylAi_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calis-and-fries-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 127,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8317489624023,
#     'longitude': -117.121040344238},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5150 Murphy Canyon Rd',
#     'address2': 'Ste 109',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5150 Murphy Canyon Rd',
#      'Ste 109',
#      'San Diego, CA 92123']},
#    'phone': '+18582797733',
#    'display_phone': '(858) 279-7733',
#    'distance': 5484.046954169857},
#   {'id': '1xNYUQqnSKcQPxN-sApuIQ',
#    'alias': 'rigobertos-taco-shop-san-diego-2',
#    'name': "Rigoberto's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6UqhhD8VxeLmS0Cvh658-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rigobertos-taco-shop-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 816,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.87994, 'longitude': -117.16208},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7094 Miramar Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7094 Miramar Rd', 'San Diego, CA 92121']},
#    'phone': '+18582710170',
#    'display_phone': '(858) 271-0170',
#    'distance': 9949.517819456574},
#   {'id': 'c2iFpIROV9OVK3wd24J0Tw',
#    'alias': 'la-vecindad-neighborhood-tacos-san-diego-2',
#    'name': 'La Vecindad Neighborhood Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cm9oF29wlGv5Z3QaeYoUZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vecindad-neighborhood-tacos-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 998,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7476563, 'longitude': -117.1602513},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3827 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3827 5th Ave', 'San Diego, CA 92103']},
#    'phone': '+16195012885',
#    'display_phone': '(619) 501-2885',
#    'distance': 4819.13577936874},
#   {'id': 'GZJQc4hMTibVNaS3_ksF-Q',
#    'alias': 'la-playa-taco-shop-san-diego',
#    'name': 'La Playa Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y8Ei5lv5R-Gw__J4vAa7lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-playa-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1194,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.78939, 'longitude': -117.25308},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3973 Mission Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3973 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18584887405',
#    'display_phone': '(858) 488-7405',
#    'distance': 9258.62822052106},
#   {'id': 'DAZ6F_1zDZp3qa6X1OjuCg',
#    'alias': 'city-tacos-san-diego',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s0Z9Zic1xLzty6BXXAGsgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1940,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.74885802959357,
#     'longitude': -117.12943449824668},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3028 University Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3028 University Ave', 'San Diego, CA 92104']},
#    'phone': '+16192962303',
#    'display_phone': '(619) 296-2303',
#    'distance': 5179.104840792347},
#   {'id': 'TMPbnPfCRUv7adgOKwJ3wA',
#    'alias': 'tacos-el-panson-san-diego',
#    'name': 'Tacos El Panson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B1F0475bQcM8IVMbxVs_EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-panson-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 346,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.75486, 'longitude': -117.09907},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4433 El Cajon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4433 El Cajon Blvd', 'San Diego, CA 92115']},
#    'phone': '+16192412222',
#    'display_phone': '(619) 241-2222',
#    'distance': 6495.604013282882},
#   {'id': 'iVWC7ivyOVNJsnxSreMopg',
#    'alias': 'la-palapa-taco-shop-san-diego',
#    'name': 'La Palapa Taco Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOLRZe9i1H3elinbAxbhkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-palapa-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 41,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.823277, 'longitude': -117.214099},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4386 Moraga Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4386 Moraga Ave', 'San Diego, CA 92117']},
#    'phone': '+18584901190',
#    'display_phone': '(858) 490-1190',
#    'distance': 6687.746793171172},
#   {'id': 'OAnJnRs9-w5rtSK3TBxH3A',
#    'alias': 'trujillos-taco-shop-san-diego-4',
#    'name': "Trujillo's Taco Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B0RPwK9V-zy1rVNFxL-a6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trujillos-taco-shop-san-diego-4?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 125,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.76608, 'longitude': -117.06045},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6450 El Cajon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6450 El Cajon Blvd', 'San Diego, CA 92115']},
#    'phone': '+16195821451',
#    'display_phone': '(619) 582-1451',
#    'distance': 9169.43379785958},
#   {'id': 'calNCZE_Ub2W4TXcSoaeTg',
#    'alias': 'baja-bay-grill-san-diego',
#    'name': 'Baja Bay Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lW6y-aJZAwlYCqwz76_wsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baja-bay-grill-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 46,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7956947629753,
#     'longitude': -117.251699902117},
#    'transactions': [],
#    'location': {'address1': '980 Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['980 Grand Ave', 'San Diego, CA 92109']},
#    'phone': '+18588867927',
#    'display_phone': '(858) 886-7927',
#    'distance': 9142.385375391443},
#   {'id': 'n6J_j_nUxl__kRZU9vbE6g',
#    'alias': 'taqueria-los-chuchys-san-diego',
#    'name': 'Taqueria Los Chuchys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9RlZcvufvkieopnDoyskQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-los-chuchys-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 149,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.71101, 'longitude': -117.16077},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '543 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['543 4th Ave', 'San Diego, CA 92101']},
#    'phone': '+16193268385',
#    'display_phone': '(619) 326-8385',
#    'distance': 8872.76443219748},
#   {'id': '9b7KyVavhVS9LDu6OADgJw',
#    'alias': 'don-roman-san-diego-2',
#    'name': 'Don Roman',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NTRxdbLBBkEgK0UMQwzxoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-roman-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 110,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.760822, 'longitude': -117.065737},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '6145 El Cajon Blvd',
#     'address2': 'Ste J',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6145 El Cajon Blvd', 'Ste J', 'San Diego, CA 92115']},
#    'phone': '+16196420800',
#    'display_phone': '(619) 642-0800',
#    'distance': 8888.11726059812},
#   {'id': 's2xzcM6Q22gy2P3Za-X61Q',
#    'alias': 'coal-bros-taqueria-san-diego',
#    'name': 'Coal Bros Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NdQ257iZIFh3IwPQ3O37tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coal-bros-taqueria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 86,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.71652, 'longitude': -117.16077},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '407 C St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['407 C St', 'San Diego, CA 92101']},
#    'phone': '+16194916389',
#    'display_phone': '(619) 491-6389',
#    'distance': 8250.223269626895},
#   {'id': 'uUTp1QA34_NBiixhfH6SfQ',
#    'alias': 'tbs-tavern-san-diego',
#    'name': 'TBS Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_og18Fw20roEhO9pvxqxYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tbs-tavern-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 56,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.773961, 'longitude': -117.142537791842},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8555 Station Village Way',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92108',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8555 Station Village Way', 'San Diego, CA 92108']},
#    'phone': '+16193594198',
#    'display_phone': '(619) 359-4198',
#    'distance': 2139.042631210627},
#   {'id': '_gpPJXtcxwpRRSJjQ8Erow',
#    'alias': 'el-rodeo-taco-shop-san-diego',
#    'name': 'El Rodeo Taco Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/os5gF3rBL1h_K1wurb1I1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rodeo-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 254,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7914183, 'longitude': -117.08195},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5149 Waring Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5149 Waring Rd', 'San Diego, CA 92120']},
#    'phone': '+16192291840',
#    'display_phone': '(619) 229-1840',
#    'distance': 6743.396009529592},
#   {'id': 'jxVkC6R-pFiH7LjYwplGfA',
#    'alias': 'burros-and-fries-san-diego-7',
#    'name': 'Burros & Fries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bWZwNsd6Cdl3a0CdQ8_ODQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burros-and-fries-san-diego-7?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 99,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.8310215849872,
#     'longitude': -117.130342068733},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '9211 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9211 Clairemont Mesa Blvd', 'San Diego, CA 92123']},
#    'phone': '+18588361277',
#    'display_phone': '(858) 836-1277',
#    'distance': 5015.522570457526},
#   {'id': 'bXJxSKWlmisvsiiZ0XueUQ',
#    'alias': 'medina-moroccan-baja-kitchen-san-diego',
#    'name': 'Medina Moroccan-Baja Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1N3VhP8Y9IpKBewMW8OU6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/medina-moroccan-baja-kitchen-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 197,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7555903, 'longitude': -117.1323809},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2850 El Cajon Blvd',
#     'address2': 'Ste 4',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2850 El Cajon Blvd', 'Ste 4', 'San Diego, CA 92104']},
#    'phone': '+16192305037',
#    'display_phone': '(619) 230-5037',
#    'distance': 4386.9401150913645},
#   {'id': 'nae47HC_0iTel79nKRV3SA',
#    'alias': 'humbertos-taco-shop-san-diego-3',
#    'name': "Humberto's Taco Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7R4gPffAFXGvGkaqxIc3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/humbertos-taco-shop-san-diego-3?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 260,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.69429, 'longitude': -117.10266},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1136 S 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1136 S 43rd St', 'San Diego, CA 92113']},
#    'phone': '+16192668433',
#    'display_phone': '(619) 266-8433',
#    'distance': 11738.734034104922},
#   {'id': 'tMxgORlnyro6R7gUpohpkA',
#    'alias': 'stars-and-stripes-taco-shop-san-diego',
#    'name': 'Stars & Stripes Travel Center',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UKj8BhWTcA59t5t_P3XH7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stars-and-stripes-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 117,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.877183, 'longitude': -117.186113},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5706 Miramar Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5706 Miramar Rd', 'San Diego, CA 92121']},
#    'phone': '+18584509776',
#    'display_phone': '(858) 450-9776',
#    'distance': 10085.202588777967},
#   {'id': 'KWIHJu11t2llkyGo7RxATg',
#    'alias': 'taco-surf-pacific-beach-san-diego',
#    'name': 'Taco Surf Pacific Beach',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ja43BUUla6QK_K6xDfknvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-surf-pacific-beach-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1004,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79876, 'longitude': -117.25585},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4657 Mission Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4657 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18582723877',
#    'display_phone': '(858) 272-3877',
#    'distance': 9572.447426149554},
#   {'id': 'RkuubU30kfYr-NzHM4BGfg',
#    'alias': 'south-beach-bar-and-grille-san-diego',
#    'name': 'South Beach Bar & Grille',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/diBbk_ll_DwXSSOe_1G9pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-beach-bar-and-grille-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 2738,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.74729, 'longitude': -117.2523},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5059 Newport Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5059 Newport Ave', 'San Diego, CA 92107']},
#    'phone': '+16192264577',
#    'display_phone': '(619) 226-4577',
#    'distance': 10381.227435856203},
#   {'id': 'Dn0c3hCvCHYPY4zPGQ2N7w',
#    'alias': 'not-not-tacos-san-diego',
#    'name': 'Not Not Tacos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OfFEgW_nR7D5_yhEyosI_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/not-not-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 311,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.723171, 'longitude': -117.167677},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '550 W Date St',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['550 W Date St', 'Ste B', 'San Diego, CA 92101']},
#    'phone': '+16192696725',
#    'display_phone': '(619) 269-6725',
#    'distance': 7601.394162934105},
#   {'id': 'gIuxWaIu2M3JlzYAPLX0bA',
#    'alias': 'taqueria-pepitos-santee',
#    'name': 'Taqueria Pepitos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Rfdl9QQOZ6iAnCdI5PK-PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-pepitos-santee?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 116,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.832895, 'longitude': -117.000421},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '8667 Fanita Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Santee',
#     'zip_code': '92071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8667 Fanita Dr', 'Santee, CA 92071']},
#    'phone': '+16195021171',
#    'display_phone': '(619) 502-1171',
#    'distance': 15103.045765244462},
#   {'id': 'a6yxQHge4tcaKGV2lt4U3A',
#    'alias': 'tuetano-taqueria-san-diego',
#    'name': 'Tuetano Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E6_C-6q1U5qw8ijVkh5blA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuetano-taqueria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 237,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.55324, 'longitude': -117.0459},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '143 W San Ysidro Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92173',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['143 W San Ysidro Blvd', 'San Diego, CA 92173']},
#    'phone': '+16198567013',
#    'display_phone': '(619) 856-7013',
#    'distance': 28272.040549042926},
#   {'id': '19x90_yOoljPPa-KDcLsLg',
#    'alias': 'harrys-taco-club-san-diego',
#    'name': "Harry's Taco Club",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vgs01b04C8fbFbBuuQ3ukg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-taco-club-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 68,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7986742786113,
#     'longitude': -117.252488136292},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4612 Cass St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4612 Cass St', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9242.174502799093},
#   {'id': 'pxnJu_rJoPFaoEbvoPCl2A',
#    'alias': 'coastal-cantina-san-diego',
#    'name': 'Coastal Cantina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HrRlrkOILXNW6sRC8T1tDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coastal-cantina-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 30,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.71447, 'longitude': -117.16045},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '431 E St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['431 E St', 'San Diego, CA 92101']},
#    'phone': '+16199156349',
#    'display_phone': '(619) 915-6349',
#    'distance': 8485.402330633437},
#   {'id': 'S7wOVlUXorhT1LWNDBPVDw',
#    'alias': 'birrieria-la-loteria-san-diego',
#    'name': 'Birrieria La Loteria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dU7lGRkdaz1febPc8Y4Ang/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birrieria-la-loteria-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 18,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.7403436, 'longitude': -117.0499749},
#    'transactions': [],
#    'location': {'address1': '6873 Federal Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '91945',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6873 Federal Blvd', 'San Diego, CA 91945']},
#    'phone': '+16193924886',
#    'display_phone': '(619) 392-4886',
#    'distance': 11222.733872399245},
#   {'id': 'fSN6srCjgfj3KBDpSHn30w',
#    'alias': 'el-jefe-san-diego',
#    'name': 'El Jefe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PLEawKHw-1YFenRVVHHfjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-jefe-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 5,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.770047, 'longitude': -117.252631},
#    'transactions': [],
#    'location': {'address1': '3105 Ocean Front Walk',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3105 Ocean Front Walk', 'San Diego, CA 92109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9493.386585559841},
#   {'id': 'k5iA70JBHhY8ucLXGR0npA',
#    'alias': 'el-charro-taco-shop-san-diego-2',
#    'name': 'El Charro Taco Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uoiQ8yu9yVwtw3OoRakF0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-charro-taco-shop-san-diego-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 75,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7505499, 'longitude': -117.21332},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3445 Midway Dr',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3445 Midway Dr', 'Ste B', 'San Diego, CA 92110']},
#    'phone': '+16192240774',
#    'display_phone': '(619) 224-0774',
#    'distance': 7115.500415585015},
#   {'id': 'vWUDpdnaWrAVdA_5IRMtxQ',
#    'alias': 'casa-de-freds-tacos-y-tequila-san-diego',
#    'name': 'Casa de Freds Tacos y Tequila',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mON6zhLyWG23an--qOtz7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-de-freds-tacos-y-tequila-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 1676,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.7526343, 'longitude': -117.1940694},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2470 San Diego Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2470 San Diego Ave', 'San Diego, CA 92110']},
#    'phone': '+16198588226',
#    'display_phone': '(619) 858-8226',
#    'distance': 5636.48370200403},
#   {'id': 'Fe6PVV6jbl2WVjdfIwdZHw',
#    'alias': 'areli-s-taco-shop-san-diego',
#    'name': 'Areli’s Taco Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PI_drAgmy2mS4pziNvTkkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/areli-s-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 8,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.798341, 'longitude': -117.245803},
#    'transactions': [],
#    'location': {'address1': '1313 Garnet Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1313 Garnet Ave', 'San Diego, CA 92109']},
#    'phone': '+18582748931',
#    'display_phone': '(858) 274-8931',
#    'distance': 8617.374734241515},
#   {'id': 'runGViQ9mHIh5iSfcx-Eig',
#    'alias': 'mr-birria-santee-2',
#    'name': 'Mr Birria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rkegp4f5xiQb4JJ4or3edw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-birria-santee-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 98,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.83953, 'longitude': -116.99629},
#    'transactions': [],
#    'location': {'address1': '8926 Carlton Hills Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Santee',
#     'zip_code': '92071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8926 Carlton Hills Blvd', 'Santee, CA 92071']},
#    'phone': '+16193280058',
#    'display_phone': '(619) 328-0058',
#    'distance': 15714.023738733664},
#   {'id': '6utCiXqnaY5PfcmwDlRqcw',
#    'alias': 'city-tacos-san-diego-4',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jggqyoEyayIptuGpB9Bp7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego-4?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 41,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.904407, 'longitude': -117.22788},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11045 Roselle St',
#     'address2': 'Ste 100',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['11045 Roselle St', 'Ste 100', 'San Diego, CA 92121']},
#    'phone': '+18582175374',
#    'display_phone': '(858) 217-5374',
#    'distance': 14409.437718360752},
#   {'id': 'DNtaym0EPp3Y8S3B7Sn82Q',
#    'alias': 'la-taqueria-tijuana-san-diego',
#    'name': 'La Taqueria Tijuana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HcF_SaSxxuWlEeFJTrmQkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-taqueria-tijuana-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 44,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.58351, 'longitude': -117.09582},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1753 Palm Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92153',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1753 Palm Ave', 'San Diego, CA 92153']},
#    'phone': '+16193139127',
#    'display_phone': '(619) 313-9127',
#    'distance': 23666.719090833034},
#   {'id': 'vfH0YVtRs4g1ykpb6Fnp_w',
#    'alias': 'raymundo-s-taco-shop-la-jolla',
#    'name': 'Raymundo’s Taco Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1H4uORpKqxmqVyhzsIC2NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raymundo-s-taco-shop-la-jolla?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 9,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.847568, 'longitude': -117.272435},
#    'transactions': [],
#    'location': {'address1': '7918 Ivanhoe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'La Jolla',
#     'zip_code': '92037',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7918 Ivanhoe Ave', 'La Jolla, CA 92037']},
#    'phone': '+18583526867',
#    'display_phone': '(858) 352-6867',
#    'distance': 12752.17856829004},
#   {'id': 'pFwm-rdUE17jeObSsQMRHg',
#    'alias': 'toritos-mexican-grill-san-diego',
#    'name': 'Toritos Mexican Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fCCtwMKMk32syYr6q_SrFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toritos-mexican-grill-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 36,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.584831, 'longitude': -117.0390434},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4370 Palm Ave',
#     'address2': 'Ste E',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92154',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4370 Palm Ave', 'Ste E', 'San Diego, CA 92154']},
#    'phone': '+16199476005',
#    'display_phone': '(619) 947-6005',
#    'distance': 25283.677491546805},
#   {'id': 'lfOv3T15_aeSLydomYD22w',
#    'alias': 'ruribertos-taco-shop-san-diego',
#    'name': "Ruriberto's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oJdos6olwWAQTWyeXQM6RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruribertos-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 356,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.77221, 'longitude': -117.25141},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3202 Mission Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3202 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18584881610',
#    'display_phone': '(858) 488-1610',
#    'distance': 9327.301267862566},
#   {'id': 'ZYaOk1IY_6TpgW0e4wW2Iw',
#    'alias': 'tacos-el-gallo-el-cajon',
#    'name': 'Tacos El Gallo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m3LUArAQ8rdBGp7WcLxsYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-gallo-el-cajon?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 65,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.801604, 'longitude': -116.935444},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '569 N 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'El Cajon',
#     'zip_code': '92021',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['569 N 2nd St', 'El Cajon, CA 92021']},
#    'phone': '+16194995500',
#    'display_phone': '(619) 499-5500',
#    'distance': 20476.564819535284},
#   {'id': '-ztxa5dsVmIYp49d2dsg2A',
#    'alias': 'tacos-and-gorditas-san-diego',
#    'name': 'Tacos and Gorditas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Utd0LA-zml7ytmUAam-lfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-and-gorditas-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 203,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.5967198, 'longitude': -116.9028125},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2445 Otay Center Dr',
#     'address2': 'Ste 112',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92154',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2445 Otay Center Dr',
#      'Ste 112',
#      'San Diego, CA 92154']},
#    'phone': '+16197583794',
#    'display_phone': '(619) 758-3794',
#    'distance': 31898.331738325523},
#   {'id': 'yDcOrQW2aQZs8aN323-yIw',
#    'alias': 'rolandos-taco-shop-san-diego-11',
#    'name': "Rolando's Taco Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ZNaeVk6ZMNyTeT4NfB7CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rolandos-taco-shop-san-diego-11?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 93,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.7837175, 'longitude': -117.098186},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6030 Mission Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92120',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6030 Mission Gorge Rd', 'San Diego, CA 92120']},
#    'phone': '+16192835369',
#    'display_phone': '(619) 283-5369',
#    'distance': 5258.5465934165195},
#   {'id': 'IEafp8ghEvcZxUKl4SAvZg',
#    'alias': 'habanero-street-tacos-san-diego',
#    'name': 'Habanero Street Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pQz_FSW2Jw3--C98TZTg8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habanero-street-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 21,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7613133, 'longitude': -117.1258361},
#    'transactions': [],
#    'location': {'address1': '4607 Iowa St',
#     'address2': 'Ste 4',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4607 Iowa St', 'Ste 4', 'San Diego, CA 92116']},
#    'phone': '+17204019680',
#    'display_phone': '(720) 401-9680',
#    'distance': 4190.116510808968},
#   {'id': 'lufX3zagRcN8yHCGh_xagA',
#    'alias': 'city-tacos-la-mesa-2',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ez2kLI-E0NaiERWhroARWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-la-mesa-2?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 673,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7650642806573,
#     'longitude': -117.018342186508},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8325 La Mesa Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'La Mesa',
#     'zip_code': '91942',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8325 La Mesa Blvd', 'La Mesa, CA 91942']},
#    'phone': '+16194677999',
#    'display_phone': '(619) 467-7999',
#    'distance': 13003.460242020055},
#   {'id': 'LgnhE7hbMA2BR4DBkUSLSw',
#    'alias': 'rodrigos-taco-shop-san-diego',
#    'name': "Rodrigo's Taco Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yFrrRhtgZMUhjLKeCnj9iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodrigos-taco-shop-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 247,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9611601081819,
#     'longitude': -117.113958641849},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '9926 Carmel Mountain Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92129',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9926 Carmel Mountain Rd', 'San Diego, CA 92129']},
#    'phone': '+18585382067',
#    'display_phone': '(858) 538-2067',
#    'distance': 19335.36158085786},
#   {'id': 'UPbnh-gStJbgCmqxzwv8WA',
#    'alias': 'chula-tacos-san-diego',
#    'name': 'Chula Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JLhavNGcCwfi6Uf37hIPVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chula-tacos-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 32,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7112269, 'longitude': -117.1020353},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4301 Market St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4301 Market St', 'San Diego, CA 92102']},
#    'phone': '+16194512517',
#    'display_phone': '(619) 451-2517',
#    'distance': 10076.106246810241},
#   {'id': 'doiIEXqFp0Txa_40xFotMQ',
#    'alias': 'robertos-taco-shop-san-diego-28',
#    'name': "Roberto's Taco Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IIcroqZRF7q78yIZyd95jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertos-taco-shop-san-diego-28?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 249,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 32.74977, 'longitude': -117.24246},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '4770 Voltaire St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4770 Voltaire St', 'San Diego, CA 92107']},
#    'phone': '+16195231162',
#    'display_phone': '(619) 523-1162',
#    'distance': 9422.040485020727},
#   {'id': 'nD1yxnwQIfcFlf0ex6FGlg',
#    'alias': 'city-tacos-san-diego-5',
#    'name': 'City Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3drOO9a-K9hZ0BnLen4DZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-tacos-san-diego-5?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 55,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.796612400000356,
#     'longitude': -117.25591870000143},
#    'transactions': ['delivery'],
#    'location': {'address1': '4516 Mission Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4516 Mission Blvd', 'San Diego, CA 92109']},
#    'phone': '+18582844239',
#    'display_phone': '(858) 284-4239',
#    'distance': 9542.590129274426},
#   {'id': '0mOdEBn9EyeOYDfOXs2p7w',
#    'alias': 'taqueria-revolucion-chula-vista',
#    'name': 'Taqueria Revolucion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fdeif5HjiWYzko-KVMqqUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-revolucion-chula-vista?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 769,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.6482277704582,
#     'longitude': -117.059008531739},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3001 Bonita Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chula Vista',
#     'zip_code': '91910',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3001 Bonita Rd', 'Chula Vista, CA 91910']},
#    'phone': '+16199349191',
#    'display_phone': '(619) 934-9191',
#    'distance': 18155.55143412463},
#   {'id': 'YzPKpl5mRNYFlVm16PItsQ',
#    'alias': 'karinas-cantina-la-jolla',
#    'name': "Karina's Cantina",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P-BNB-UPTUmEsW13AydFCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karinas-cantina-la-jolla?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 29,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.84259, 'longitude': -117.27186},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1055 Torrey Pines Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'La Jolla',
#     'zip_code': '92037',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1055 Torrey Pines Rd', 'La Jolla, CA 92037']},
#    'phone': '+18589990744',
#    'display_phone': '(858) 999-0744',
#    'distance': 12438.844612643088},
#   {'id': 'c-dMCoJgUAtp6YcdJy1RGA',
#    'alias': 'el-rey-tacos-a-vapor-san-diego',
#    'name': 'El Rey Tacos a Vapor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dUdYyUR1kIsAl37CPXovZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rey-tacos-a-vapor-san-diego?adjust_creative=gHLL75R-K8KFjVe5w2TXkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gHLL75R-K8KFjVe5w2TXkg',
#    'review_count': 3,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.75572833, 'longitude': -117.14226667},
#    'transactions': [],
#    'location': {'address1': '2104 El Cajon Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92104',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2104 El Cajon Blvd', 'San Diego, CA 92104']},
#    'phone': '+16194542953',
#    'display_phone': '(619) 454-2953',
#    'distance': 4025.8768080007208}],
#  'total': 500,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}

# %%
with open('yelpTacosLoc.json', 'w') as json_file:
    json.dump(data, json_file)
